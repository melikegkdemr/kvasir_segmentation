# %% [markdown]
# # Importing The libraries

# %%
import os
import cv2
import random
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
IMG_CHANNELS = 3
IMG_WIDTH = 256
IMG_HEIGHT = 256

# %%
images_path = "/kaggle/input/kvasir-dataset-for-classification-and-segmentation/kvasir-seg/Kvasir-SEG/images"
mask_path = "/kaggle/input/kvasir-dataset-for-classification-and-segmentation/kvasir-seg/Kvasir-SEG/masks"

# %%
img_ids = next(os.walk(images_path))[2]
mask_ids = next(os.walk(mask_path))[2]

# %%
X = np.zeros((len(img_ids), 256, 256, 3), dtype=np.uint8)
y = np.zeros((len(mask_ids), 256, 256, 1), dtype=np.bool_)

# %%
for n,img in enumerate(os.listdir(images_path)):
    file_path = os.path.join(images_path, img)
    image = imread(file_path)
    image = resize(image, (256, 256), mode="constant", preserve_range=True)
    X[n] = image

# %%
for n,mask in enumerate(os.listdir(mask_path)):
    file_path = os.path.join(mask_path, mask)
    mask = imread(file_path)
    mask = rgb2gray(mask)
    mask = np.expand_dims(resize(mask, (256, 256), mode="constant", preserve_range=True), axis=-1)
    y[n] = mask

# %%
image_random = random.randint(0, len(X))
imshow(X[image_random])
plt.show()
plt.imshow(np.squeeze(y[image_random]))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(f"X_train.shape: {X_train.shape}\nY_train.shape: {y_train.shape}")
# Out:
# X_train.shape: (670, 256, 256, 3)
# Y_train.shape: (670, 256, 256, 1)

# %% [markdown]
# # MODEL:

# %% [markdown]
# ## UNet model for image segmentation [Semantic].
#
# [Paper](https://arxiv.org/abs/1505.04597)

# %%
input = tf.keras.layers.Input((256, 256, 3))

# reduce image config
s = tf.keras.layers.Lambda(lambda x: x / 256)(input)

# block 1
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation="relu", kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

# block 2
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

# block 3
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
c3  = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

# block 4
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D((2, 2))(c4)

# block 5
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
p5 = tf.keras.layers.MaxPooling2D((2, 2))(c5)

# block 6
c6 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p5)
c6 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
c6 = tf.keras.layers.Dropout(0.3)(c6)
c6 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

# block 7 - back 1
u7 = tf.keras.layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c5])
c7 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
c7 = tf.keras.layers.Dropout(0.3)(c7)
c7 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

# block 8 - back 2
u8 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c4])
c8 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
c8 = tf.keras.layers.Dropout(0.2)(c8)
c8 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

# block 9 - back 3
u9 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c3])
c9 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
c9 = tf.keras.layers.Dropout(0.2)(c9)
c9 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

# block 10 - back 4
u10 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c9)
u10 = tf.keras.layers.concatenate([u10, c2])
c10 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u10)
c10 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c10)
c10 = tf.keras.layers.Dropout(0.1)(c10)
c10 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c10)

# block 11 - back 5
u11 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c10)
u11 = tf.keras.layers.concatenate([u11, c1])
c11 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u11)
c11 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c11)
c11 = tf.keras.layers.Dropout(0.1)(c11)
c11 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c11)

outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c11)

model = tf.keras.Model(inputs=input, outputs=outputs, name='U-NET')

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy','iou_coef'])

# %%
# function to create iou coefficient
def iou_coef(y_true, y_pred, smooth=100):
    intersection = K.sum(y_true * y_pred)
    sum = K.sum(y_true + y_pred)
    iou = (intersection + smooth) / (sum - intersection + smooth)
    return iou

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', iou_coef])

model.summary()
# Out:
# Model: "U-NET"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 256, 256, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 256, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 16) 2320        dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 128, 32) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 32) 9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 256)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 256)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 256)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 512)    1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 512)    2359808     conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 512)    0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 512)    2359808     dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 256)  524544      conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 512)  0           conv2d_transpose[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_18[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 256)  0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 256)  590080      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 128)  131200      conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_21[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 128)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 128)  147584      dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   32832       conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_24[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 64, 64)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 64)   36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 32) 8224        conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_27[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128, 32) 0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 128, 128, 32) 9248        dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 16) 2064        conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 256, 256, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 256, 256, 16) 2320        conv2d_30[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 256, 256, 16) 0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 256, 256, 16) 2320        dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 256, 256, 1)  17          conv2d_32[0][0]
# ==================================================================================================
# Total params: 11,707,729
# Trainable params: 11,707,729
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training the model.

# %%
model.fit(X_train, y_train, validation_split=0.1, batch_size=8, epochs=100)
# Out:
# Epoch 1/100
# 76/76 [==============================] - 15s 75ms/step - loss: 1.2557 - accuracy: 0.8106 - iou_coef: 0.1113 - val_loss: 0.4483 - val_accuracy: 0.8206 - val_iou_coef: 0.1240
# Epoch 2/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.4403 - accuracy: 0.8271 - iou_coef: 0.1247 - val_loss: 0.4177 - val_accuracy: 0.8206 - val_iou_coef: 0.1378
# Epoch 3/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.4149 - accuracy: 0.8273 - iou_coef: 0.1375 - val_loss: 0.4052 - val_accuracy: 0.8206 - val_iou_coef: 0.1544
# Epoch 4/100
# 76/76 [==============================] - 5s 60ms/step - loss: 0.3958 - accuracy: 0.8272 - iou_coef: 0.1532 - val_loss: 0.4006 - val_accuracy: 0.8206 - val_iou_coef: 0.1791
# Epoch 5/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3946 - accuracy: 0.8272 - iou_coef: 0.1602 - val_loss: 0.3858 - val_accuracy: 0.8206 - val_iou_coef: 0.1675
# Epoch 6/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3818 - accuracy: 0.8273 - iou_coef: 0.1726 - val_loss: 0.3822 - val_accuracy: 0.8206 - val_iou_coef: 0.1746
# Epoch 7/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3731 - accuracy: 0.8272 - iou_coef: 0.1800 - val_loss: 0.3822 - val_accuracy: 0.8206 - val_iou_coef: 0.1853
# Epoch 8/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3654 - accuracy: 0.8294 - iou_coef: 0.1887 - val_loss: 0.3933 - val_accuracy: 0.8225 - val_iou_coef: 0.2001
# Epoch 9/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3625 - accuracy: 0.8336 - iou_coef: 0.1944 - val_loss: 0.3762 - val_accuracy: 0.8224 - val_iou_coef: 0.1785
# Epoch 10/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3632 - accuracy: 0.8351 - iou_coef: 0.1981 - val_loss: 0.3769 - val_accuracy: 0.8225 - val_iou_coef: 0.1759
# Epoch 11/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3588 - accuracy: 0.8397 - iou_coef: 0.2016 - val_loss: 0.3606 - val_accuracy: 0.8332 - val_iou_coef: 0.2049
# Epoch 12/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3556 - accuracy: 0.8404 - iou_coef: 0.2076 - val_loss: 0.3717 - val_accuracy: 0.8261 - val_iou_coef: 0.1829
# Epoch 13/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3499 - accuracy: 0.8444 - iou_coef: 0.2179 - val_loss: 0.3612 - val_accuracy: 0.8304 - val_iou_coef: 0.1931
# Epoch 14/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3556 - accuracy: 0.8369 - iou_coef: 0.2084 - val_loss: 0.3769 - val_accuracy: 0.8233 - val_iou_coef: 0.2161
# Epoch 15/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3523 - accuracy: 0.8421 - iou_coef: 0.2143 - val_loss: 0.3566 - val_accuracy: 0.8330 - val_iou_coef: 0.2089
# Epoch 16/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3538 - accuracy: 0.8433 - iou_coef: 0.2146 - val_loss: 0.3607 - val_accuracy: 0.8278 - val_iou_coef: 0.1933
# Epoch 17/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3523 - accuracy: 0.8419 - iou_coef: 0.2111 - val_loss: 0.3509 - val_accuracy: 0.8336 - val_iou_coef: 0.2171
# Epoch 18/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3423 - accuracy: 0.8485 - iou_coef: 0.2295 - val_loss: 0.3600 - val_accuracy: 0.8304 - val_iou_coef: 0.2368
# Epoch 19/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3554 - accuracy: 0.8386 - iou_coef: 0.2109 - val_loss: 0.3588 - val_accuracy: 0.8288 - val_iou_coef: 0.1865
# Epoch 20/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3396 - accuracy: 0.8502 - iou_coef: 0.2317 - val_loss: 0.3603 - val_accuracy: 0.8372 - val_iou_coef: 0.2273
# Epoch 21/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3432 - accuracy: 0.8490 - iou_coef: 0.2338 - val_loss: 0.3684 - val_accuracy: 0.8274 - val_iou_coef: 0.1754
# Epoch 22/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3386 - accuracy: 0.8489 - iou_coef: 0.2296 - val_loss: 0.3520 - val_accuracy: 0.8360 - val_iou_coef: 0.2107
# Epoch 23/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3363 - accuracy: 0.8536 - iou_coef: 0.2413 - val_loss: 0.3517 - val_accuracy: 0.8392 - val_iou_coef: 0.2080
# Epoch 24/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3357 - accuracy: 0.8550 - iou_coef: 0.2411 - val_loss: 0.3647 - val_accuracy: 0.8307 - val_iou_coef: 0.1820
# Epoch 25/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3287 - accuracy: 0.8575 - iou_coef: 0.2518 - val_loss: 0.3324 - val_accuracy: 0.8429 - val_iou_coef: 0.2634
# Epoch 26/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3330 - accuracy: 0.8548 - iou_coef: 0.2465 - val_loss: 0.3443 - val_accuracy: 0.8462 - val_iou_coef: 0.2217
# Epoch 27/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3183 - accuracy: 0.8638 - iou_coef: 0.2663 - val_loss: 0.3247 - val_accuracy: 0.8569 - val_iou_coef: 0.2638
# Epoch 28/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3038 - accuracy: 0.8735 - iou_coef: 0.2994 - val_loss: 0.3556 - val_accuracy: 0.8520 - val_iou_coef: 0.3163
# Epoch 29/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3117 - accuracy: 0.8713 - iou_coef: 0.2825 - val_loss: 0.3141 - val_accuracy: 0.8594 - val_iou_coef: 0.3185
# Epoch 30/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3011 - accuracy: 0.8739 - iou_coef: 0.3011 - val_loss: 0.2967 - val_accuracy: 0.8679 - val_iou_coef: 0.3169
# Epoch 31/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2834 - accuracy: 0.8859 - iou_coef: 0.3442 - val_loss: 0.3106 - val_accuracy: 0.8661 - val_iou_coef: 0.2642
# Epoch 32/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2851 - accuracy: 0.8830 - iou_coef: 0.3184 - val_loss: 0.3318 - val_accuracy: 0.8719 - val_iou_coef: 0.3339
# Epoch 33/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2746 - accuracy: 0.8911 - iou_coef: 0.3503 - val_loss: 0.2773 - val_accuracy: 0.8837 - val_iou_coef: 0.3361
# Epoch 34/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2671 - accuracy: 0.8925 - iou_coef: 0.3652 - val_loss: 0.2819 - val_accuracy: 0.8845 - val_iou_coef: 0.3866
# Epoch 35/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2522 - accuracy: 0.9002 - iou_coef: 0.3959 - val_loss: 0.3066 - val_accuracy: 0.8735 - val_iou_coef: 0.2850
# Epoch 36/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2469 - accuracy: 0.9035 - iou_coef: 0.4013 - val_loss: 0.2906 - val_accuracy: 0.8738 - val_iou_coef: 0.3018
# Epoch 37/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2402 - accuracy: 0.9084 - iou_coef: 0.4231 - val_loss: 0.2748 - val_accuracy: 0.8881 - val_iou_coef: 0.3546
# Epoch 38/100
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2369 - accuracy: 0.9086 - iou_coef: 0.4225 - val_loss: 0.2554 - val_accuracy: 0.8935 - val_iou_coef: 0.3967
# Epoch 39/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2441 - accuracy: 0.9052 - iou_coef: 0.4141 - val_loss: 0.2554 - val_accuracy: 0.8927 - val_iou_coef: 0.3809
# Epoch 40/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2244 - accuracy: 0.9157 - iou_coef: 0.4536 - val_loss: 0.2794 - val_accuracy: 0.8885 - val_iou_coef: 0.3317
# Epoch 41/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2009 - accuracy: 0.9262 - iou_coef: 0.5018 - val_loss: 0.2647 - val_accuracy: 0.8952 - val_iou_coef: 0.3706
# Epoch 42/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1995 - accuracy: 0.9243 - iou_coef: 0.4977 - val_loss: 0.2850 - val_accuracy: 0.8907 - val_iou_coef: 0.3311
# Epoch 43/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2162 - accuracy: 0.9158 - iou_coef: 0.4611 - val_loss: 0.2796 - val_accuracy: 0.9104 - val_iou_coef: 0.4165
# Epoch 44/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2033 - accuracy: 0.9221 - iou_coef: 0.4872 - val_loss: 0.2530 - val_accuracy: 0.9021 - val_iou_coef: 0.3841
# Epoch 45/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2479 - accuracy: 0.9027 - iou_coef: 0.4080 - val_loss: 0.2668 - val_accuracy: 0.8953 - val_iou_coef: 0.3601
# Epoch 46/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2138 - accuracy: 0.9178 - iou_coef: 0.4655 - val_loss: 0.2713 - val_accuracy: 0.8931 - val_iou_coef: 0.3578
# Epoch 47/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1880 - accuracy: 0.9282 - iou_coef: 0.5230 - val_loss: 0.3017 - val_accuracy: 0.8960 - val_iou_coef: 0.3942
# Epoch 48/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1732 - accuracy: 0.9363 - iou_coef: 0.5605 - val_loss: 0.2503 - val_accuracy: 0.9005 - val_iou_coef: 0.4375
# Epoch 49/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1846 - accuracy: 0.9300 - iou_coef: 0.5251 - val_loss: 0.2708 - val_accuracy: 0.8934 - val_iou_coef: 0.3823
# Epoch 50/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1819 - accuracy: 0.9325 - iou_coef: 0.5395 - val_loss: 0.2686 - val_accuracy: 0.8948 - val_iou_coef: 0.3746
# Epoch 51/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1761 - accuracy: 0.9323 - iou_coef: 0.5463 - val_loss: 0.2796 - val_accuracy: 0.8927 - val_iou_coef: 0.3948
# Epoch 52/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1630 - accuracy: 0.9382 - iou_coef: 0.5735 - val_loss: 0.3266 - val_accuracy: 0.8949 - val_iou_coef: 0.3847
# Epoch 53/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1676 - accuracy: 0.9387 - iou_coef: 0.5694 - val_loss: 0.2335 - val_accuracy: 0.9058 - val_iou_coef: 0.4941
# Epoch 54/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1720 - accuracy: 0.9342 - iou_coef: 0.5517 - val_loss: 0.2507 - val_accuracy: 0.9052 - val_iou_coef: 0.4375
# Epoch 55/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1489 - accuracy: 0.9441 - iou_coef: 0.6047 - val_loss: 0.3353 - val_accuracy: 0.8963 - val_iou_coef: 0.3685
# Epoch 56/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1483 - accuracy: 0.9456 - iou_coef: 0.6081 - val_loss: 0.2854 - val_accuracy: 0.9021 - val_iou_coef: 0.4619
# Epoch 57/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1317 - accuracy: 0.9498 - iou_coef: 0.6378 - val_loss: 0.2991 - val_accuracy: 0.8964 - val_iou_coef: 0.4922
# Epoch 58/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1621 - accuracy: 0.9403 - iou_coef: 0.5717 - val_loss: 0.2599 - val_accuracy: 0.8997 - val_iou_coef: 0.4349
# Epoch 59/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1382 - accuracy: 0.9488 - iou_coef: 0.6347 - val_loss: 0.2867 - val_accuracy: 0.8989 - val_iou_coef: 0.4456
# Epoch 60/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1336 - accuracy: 0.9512 - iou_coef: 0.6343 - val_loss: 0.2498 - val_accuracy: 0.8924 - val_iou_coef: 0.4185
# Epoch 61/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1387 - accuracy: 0.9484 - iou_coef: 0.6277 - val_loss: 0.2856 - val_accuracy: 0.8929 - val_iou_coef: 0.4717
# Epoch 62/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1265 - accuracy: 0.9529 - iou_coef: 0.6540 - val_loss: 0.2350 - val_accuracy: 0.8989 - val_iou_coef: 0.4402
# Epoch 63/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1133 - accuracy: 0.9573 - iou_coef: 0.6813 - val_loss: 0.3192 - val_accuracy: 0.8902 - val_iou_coef: 0.3714
# Epoch 64/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1093 - accuracy: 0.9585 - iou_coef: 0.6880 - val_loss: 0.2732 - val_accuracy: 0.9016 - val_iou_coef: 0.4591
# Epoch 65/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1198 - accuracy: 0.9545 - iou_coef: 0.6660 - val_loss: 0.2371 - val_accuracy: 0.9095 - val_iou_coef: 0.5238
# Epoch 66/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1130 - accuracy: 0.9569 - iou_coef: 0.6788 - val_loss: 0.2468 - val_accuracy: 0.9069 - val_iou_coef: 0.4970
# Epoch 67/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1082 - accuracy: 0.9589 - iou_coef: 0.6915 - val_loss: 0.2334 - val_accuracy: 0.9117 - val_iou_coef: 0.4941
# Epoch 68/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1442 - accuracy: 0.9462 - iou_coef: 0.6104 - val_loss: 0.2651 - val_accuracy: 0.8988 - val_iou_coef: 0.4667
# Epoch 69/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1019 - accuracy: 0.9613 - iou_coef: 0.7056 - val_loss: 0.3394 - val_accuracy: 0.8970 - val_iou_coef: 0.4208
# Epoch 70/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0941 - accuracy: 0.9631 - iou_coef: 0.7301 - val_loss: 0.2634 - val_accuracy: 0.9110 - val_iou_coef: 0.5164
# Epoch 71/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0886 - accuracy: 0.9666 - iou_coef: 0.7466 - val_loss: 0.3477 - val_accuracy: 0.8996 - val_iou_coef: 0.4357
# Epoch 72/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0964 - accuracy: 0.9641 - iou_coef: 0.7236 - val_loss: 0.2774 - val_accuracy: 0.9120 - val_iou_coef: 0.5230
# Epoch 73/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0906 - accuracy: 0.9653 - iou_coef: 0.7365 - val_loss: 0.2343 - val_accuracy: 0.9083 - val_iou_coef: 0.5177
# Epoch 74/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1038 - accuracy: 0.9592 - iou_coef: 0.6984 - val_loss: 0.2956 - val_accuracy: 0.9009 - val_iou_coef: 0.4769
# Epoch 75/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1023 - accuracy: 0.9607 - iou_coef: 0.7069 - val_loss: 0.2666 - val_accuracy: 0.9054 - val_iou_coef: 0.4865
# Epoch 76/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0841 - accuracy: 0.9691 - iou_coef: 0.7522 - val_loss: 0.2815 - val_accuracy: 0.9003 - val_iou_coef: 0.5428
# Epoch 77/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0842 - accuracy: 0.9677 - iou_coef: 0.7539 - val_loss: 0.2741 - val_accuracy: 0.9044 - val_iou_coef: 0.4880
# Epoch 78/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1115 - accuracy: 0.9584 - iou_coef: 0.6871 - val_loss: 0.2470 - val_accuracy: 0.8933 - val_iou_coef: 0.4416
# Epoch 79/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0997 - accuracy: 0.9612 - iou_coef: 0.7096 - val_loss: 0.2880 - val_accuracy: 0.9001 - val_iou_coef: 0.4939
# Epoch 80/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0792 - accuracy: 0.9700 - iou_coef: 0.7627 - val_loss: 0.3029 - val_accuracy: 0.9013 - val_iou_coef: 0.4932
# Epoch 81/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0688 - accuracy: 0.9739 - iou_coef: 0.7882 - val_loss: 0.3106 - val_accuracy: 0.9045 - val_iou_coef: 0.4929
# Epoch 82/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0685 - accuracy: 0.9735 - iou_coef: 0.7916 - val_loss: 0.3065 - val_accuracy: 0.9112 - val_iou_coef: 0.5427
# Epoch 83/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0697 - accuracy: 0.9737 - iou_coef: 0.7886 - val_loss: 0.2998 - val_accuracy: 0.9072 - val_iou_coef: 0.5469
# Epoch 84/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0705 - accuracy: 0.9726 - iou_coef: 0.7854 - val_loss: 0.3249 - val_accuracy: 0.8970 - val_iou_coef: 0.5031
# Epoch 85/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0626 - accuracy: 0.9752 - iou_coef: 0.8020 - val_loss: 0.3056 - val_accuracy: 0.9049 - val_iou_coef: 0.5132
# Epoch 86/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0818 - accuracy: 0.9697 - iou_coef: 0.7607 - val_loss: 0.3342 - val_accuracy: 0.9065 - val_iou_coef: 0.5134
# Epoch 87/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0682 - accuracy: 0.9731 - iou_coef: 0.7929 - val_loss: 0.3389 - val_accuracy: 0.8975 - val_iou_coef: 0.5192
# Epoch 88/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0569 - accuracy: 0.9776 - iou_coef: 0.8189 - val_loss: 0.2927 - val_accuracy: 0.9124 - val_iou_coef: 0.5549
# Epoch 89/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0635 - accuracy: 0.9752 - iou_coef: 0.8045 - val_loss: 0.4091 - val_accuracy: 0.8943 - val_iou_coef: 0.5423
# Epoch 90/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0881 - accuracy: 0.9668 - iou_coef: 0.7455 - val_loss: 0.3079 - val_accuracy: 0.8948 - val_iou_coef: 0.4100
# Epoch 91/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1391 - accuracy: 0.9508 - iou_coef: 0.6259 - val_loss: 0.2516 - val_accuracy: 0.9193 - val_iou_coef: 0.5822
# Epoch 92/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.1020 - accuracy: 0.9618 - iou_coef: 0.7152 - val_loss: 0.2857 - val_accuracy: 0.8966 - val_iou_coef: 0.4790
# Epoch 93/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0916 - accuracy: 0.9667 - iou_coef: 0.7357 - val_loss: 0.2849 - val_accuracy: 0.9035 - val_iou_coef: 0.5259
# Epoch 94/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0685 - accuracy: 0.9730 - iou_coef: 0.7937 - val_loss: 0.3148 - val_accuracy: 0.9028 - val_iou_coef: 0.5124
# Epoch 95/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0657 - accuracy: 0.9749 - iou_coef: 0.7997 - val_loss: 0.2633 - val_accuracy: 0.9176 - val_iou_coef: 0.5703
# Epoch 96/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0547 - accuracy: 0.9788 - iou_coef: 0.8234 - val_loss: 0.3178 - val_accuracy: 0.9068 - val_iou_coef: 0.5174
# Epoch 97/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0515 - accuracy: 0.9798 - iou_coef: 0.8350 - val_loss: 0.3195 - val_accuracy: 0.9129 - val_iou_coef: 0.5420
# Epoch 98/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0534 - accuracy: 0.9789 - iou_coef: 0.8315 - val_loss: 0.3610 - val_accuracy: 0.9060 - val_iou_coef: 0.5441
# Epoch 99/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0548 - accuracy: 0.9787 - iou_coef: 0.8246 - val_loss: 0.3059 - val_accuracy: 0.9040 - val_iou_coef: 0.5353
# Epoch 100/100
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0482 - accuracy: 0.9806 - iou_coef: 0.8440 - val_loss: 0.3321 - val_accuracy: 0.9053 - val_iou_coef: 0.5218

# %% [markdown]
# ## PREDICTED IMAGE:

# %%
ind = random.randint(0, len(X_test))
img = X_test[ind]
predictions = model.predict(np.expand_dims(img, axis=0), verbose=0)
plt.figure(figsize=(15, 12))
plt.subplot(1, 3, 1)
plt.title("original image")
plt.imshow(np.squeeze(img))
plt.subplot(1, 3, 2)
plt.title("predicted mask")
plt.imshow(np.squeeze(predictions))
plt.subplot(1, 3, 3)
plt.title("original mask")
plt.imshow(np.squeeze(img))
# plt.imshow(msk,alpha=0.5)
plt.imshow(np.squeeze(predictions), alpha=0.5)
plt.show()

# %%
ind = random.randint(0, len(X_test))
img = X_test[ind]
predMask = model.predict(np.expand_dims(img, axis=0), verbose=0)
fig = plt.figure(figsize=(15, 12))
ax1 = fig.add_subplot(1, 3, 1)
ax1.set_title("original image")
ax1.imshow(X_test[ind])
ax2 = fig.add_subplot(1, 3, 2)
ax2.set_title("original mask")
ax2.imshow(np.squeeze(y_test[ind]))
ax3 = fig.add_subplot(1, 3, 3)
ax3.set_title("pred mask")
ax3.imshow(np.squeeze(predMask))
